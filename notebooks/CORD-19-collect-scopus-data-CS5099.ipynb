# %% [markdown]
# # CORD-19 Collect SCOPUS data

# %% [markdown]
# In general, this notebook is designated to collect additional data via the Elsevier SCOPUS API to enrich the analysis.
# https://dev.elsevier.com/

# %% [markdown]
# First, relevant packages must be imported into the notebook.

# %%
import numpy as np
import pandas as pd
import csv
import ast
import collections
import matplotlib.pyplot as plt
import re
import time
import json
from urllib.parse import urlparse
from collections import Counter
from elsapy.elsclient import ElsClient
from elsapy.elsdoc import FullDoc, AbsDoc
from elsapy.elssearch import ElsSearch
from pybtex.database import parse_file, BibliographyData, Entry

# %% [markdown]
# Retrieve columns from the CORD19 CSV and store the data to a variable.

# %%
CORD19_CSV = pd.read_csv('../data/cord-19/CORD19_software_mentions.csv')

# %% [markdown]
# Check the length of the column containing doi's.

# %%
len(CORD19_CSV['doi'])
# Out:
# 77448

# %% [markdown]
# Display the column doi to see if there are inconsistencies such as NaN's. Subsequently, the existence of NaN's requires specific consideration.

# %%
doi = CORD19_CSV['doi']
doi
# Out:
# 0                                 NaN
# 1          10.1016/j.regg.2021.01.002
# 2           10.1016/j.rec.2020.08.002
# 3        10.1016/j.vetmic.2006.11.026
# 4                   10.3390/v12080849
#                      ...
# 77443      10.1007/s11229-020-02869-9
# 77444                             NaN
# 77445     10.1101/2020.05.13.20100206
# 77446      10.1007/s42991-020-00052-8
# 77447     10.1101/2020.09.14.20194670
# Name: doi, Length: 77448, dtype: object

# %% [markdown]
# Create a series with solely unique values and neglect NaN's. It is important to sort the unique values. Otherwise, the method is creating different results after restarting the notebook.

# %%
doi_counted = doi.value_counts().sort_index(ascending=True)
doi_counted
# Out:
# 10.1001/jamainternmed.2020.1369       1
# 10.1001/jamanetworkopen.2020.16382    1
# 10.1001/jamanetworkopen.2020.17521    1
# 10.1001/jamanetworkopen.2020.20485    1
# 10.1001/jamanetworkopen.2020.24984    1
#                                      ..
# 10.9745/ghsp-d-20-00115               1
# 10.9745/ghsp-d-20-00171               1
# 10.9745/ghsp-d-20-00218               1
# 10.9758/cpn.2020.18.4.607             1
# 10.9781/ijimai.2020.02.002            1
# Name: doi, Length: 74302, dtype: int64

# %% [markdown]
# The following function determines the requested information from the Scopus API.

# %%
#Code adapted from https://github.com/ElsevierDev/elsapy/blob/master/exampleProg.py
def fetch_scopus_api(client, doi):
    """obtain additional paper information from scopus by doi
    """
    doc_srch = ElsSearch("DOI("+doi+")",'scopus')
    doc_srch.execute(client, get_all = True)
    try:
        scopus_id=doc_srch.results[0]["dc:identifier"].split(":")[1]
        scp_doc = AbsDoc(scp_id = scopus_id)
        if scp_doc.read(client):
            scp_doc.write()   
        else:
            print ("Read document failed.")
        return scp_doc.data
    except:
        return None

# %% [markdown]
# Thusly, the configuration file is set up and contains an API key. For further information visit the following website: https://github.com/ElsevierDev/elsapy/blob/master/CONFIG.md

# %%
con_file = open("config.json")
config = json.load(con_file)
con_file.close()

# %% [markdown]
# Moreover, the client is initialized with the API-Key. It is important to know that the API key needs to be valid to fetch data. Otherwise, the SCOPUS API responds with an authorisation/access error.

# %%
client = ElsClient(config['apikey'])

# %% [markdown]
# For demonstration purposes, the following cells show which data is returned by the Scopus API.

# %%
return_example = fetch_scopus_api(client, '10.1016/j.dsx.2020.04.012')
print(json.dumps(return_example, indent=2))
# Out:
# {
#   "affiliation": [
#     {
#       "affiliation-city": "New Delhi",
#       "affilname": "Jamia Hamdard",
#       "affiliation-country": "India"
#     },
#     {
#       "affiliation-city": "New Delhi",
#       "affilname": "Jamia Millia Islamia",
#       "affiliation-country": "India"
#     },
#     {
#       "affiliation-city": "New Delhi",
#       "affilname": "Indraprastha Apollo Hospitals",
#       "affiliation-country": "India"
#     }
#   ],
#   "coredata": {
#     "srctype": "j",
#     "eid": "2-s2.0-85083171050",
#     "pubmed-id": "32305024",
#     "prism:coverDate": "2020-07-01",
#     "prism:aggregationType": "Journal",
#     "prism:url": "https://api.elsevier.com/content/abstract/scopus_id/85083171050",
#     "dc:creator": {
#       "author": [
#         {
#           "ce:given-name": "Raju",
#           "preferred-name": {
#             "ce:given-name": "Raju",
#             "ce:initials": "R.",
#             "ce:surname": "Vaishya",
#             "ce:indexed-name": "Vaishya R."
#           },
#           "@seq": "1",
#           "ce:initials": "R.",
#           "@_fa": "true",
#           "affiliation": {
#             "@id": "60019286",
#             "@href": "https://api.elsevier.com/content/affiliation/affiliation_id/60019286"
#           },
#           "ce:surname": "Vaishya",
#           "@auid": "6602902951",
#           "author-url": "https://api.elsevier.com/content/author/author_id/6602902951",
#           "ce:indexed-name": "Vaishya R."
#         }
#       ]
#     },
#     "link": [
#       {
#         "@_fa": "true",
#         "@rel": "self",
#         "@href": "https://api.elsevier.com/content/abstract/scopus_id/85083171050"
#       },
#       {
#         "@_fa": "true",
#         "@rel": "scopus",
#         "@href": "https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85083171050&origin=inward"
#       },
#       {
#         "@_fa": "true",
#         "@rel": "scopus-citedby",
#         "@href": "https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85083171050&origin=inward"
#       }
#     ],
#     "source-id": "5700165201",
#     "pii": "S1871402120300771",
#     "citedby-count": "209",
#     "prism:volume": "14",
#     "subtype": "ar",
#     "dc:title": "Artificial Intelligence (AI) applications for COVID-19 pandemic",
#     "openaccess": "1",
#     "prism:issn": "18780334 18714021",
#     "prism:issueIdentifier": "4",
#     "subtypeDescription": "Article",
#     "prism:publicationName": "Diabetes and Metabolic Syndrome: Clinical Research and Reviews",
#     "prism:pageRange": "337-339",
#     "prism:endingPage": "339",
#     "openaccessFlag": "true",
#     "prism:doi": "10.1016/j.dsx.2020.04.012",
#     "prism:startingPage": "337",
#     "dc:identifier": "SCOPUS_ID:85083171050",
#     "dc:publisher": "Elsevier Ltd"
#   }
# }

# %% [markdown]
# Further analysis will be conducted with such data as fetched above.
# Therefore, two notebooks are created to analyse data linked to:
# <ul>
#   <li>affiliation (CORD-19-analyse-affiliation-data-CS5099)</li>
#   <li>coredata (CORD-19-analyse-coredata-CS5099)</li>
# </ul>

# %% [markdown]
# Due to the ethical guidelines of this project, the retrieved data is not stored completely in the directory. Before storing fetched data, the following information is removed from the response:
# <ul>
#   <li>"affilname" and "affiliation-city"</li>
#   <li>"dc:creator"</li>
# </ul>
# Therefore, the following functions transform the fetched information into an ethically correct form.

# %%
def remove_unethical_entries(json_holder):
    """
    This function receives a JSON and removes ethically sensitive data from it. Therefore, various JSON details are obeyed.
    When the removal is finished, the cleaned JSON is returned to the invoking place of this method. 
    """
    #Checking if JSON is None
    if json_holder is None:
        return json_holder
    
     #Checking if JSON is NaN
    if json_holder == "NaN":
        return None

    #JSON starts with { else [
    string_helper = str(json_holder)
    #print(string_helper[0])
    if string_helper[0] == "{":
            if 'affiliation-city' in json_holder:
                del json_holder['affiliation-city']
            if 'affilname' in json_holder:
                 del json_holder['affilname']
            if 'dc:creator' in json_holder:
                 del json_holder['dc:creator']
            return json_holder
    elif string_helper[0] == "[":
        #print(json_holder)
        for element in json_holder: 
            if 'affiliation-city' in element.keys():
                del element['affiliation-city']
            if 'affilname' in element.keys():
                 del element['affilname']
            if 'dc:creator' in element.keys():
                 del element['dc:creator']
        return json_holder

# %%
def transform_to_ethical_correct_data(df):
    """
    This functions retrives a a dataframe and invokes the function remove_unethical_entries(json) with the proper parameters.
    Subsequently, the output is an ethically correct DataFrame which is returned to the invoking place of this method.  
    """
    df_index = df.index
    len_df_index = len(df_index)
    i = 0

    while i < len_df_index:
        print("Progress: "+str(i+1) +"/"+str(len_df_index)+" Index position: "+str(df_index[i])+" (Data cleaning according to ethical guidelines.)")
        df['affiliation'][df_index[i]] = remove_unethical_entries(df['affiliation'][df_index[i]])
        df['coredata'][df_index[i]] = remove_unethical_entries(df['coredata'][df_index[i]])
        i = i + 1
    return df

# %% [markdown]
# Thusly, the already fetched SCOPUS API information is read from the disk for further processing.

# %%
df_current_extra_info = pd.DataFrame()
bool_show_df = False
try:
    df_current_extra_info = pd.read_pickle('extra_info_CS5099.pkl')
    bool_show_df = True
except:
    print("The DataFrame is empty")
    bool_show_df = True

# %% [markdown]
# If fetched information is available, it will be shown below. The data is read from the disk.

# %%
if bool_show_df == True: 
    print(df_current_extra_info)
else:
    print("There is no fetched information available.")
# Out:
#                                              affiliation  \
# 0      [{'affiliation-country': 'United States'}, {'a...
# 1      [{'affiliation-country': 'United States'}, {'a...
# 2      [{'affiliation-country': 'United States'}, {'a...
# 3      [{'affiliation-country': 'United States'}, {'a...
# 4      [{'affiliation-country': 'United States'}, {'a...
# ...                                                  ...
# 74297           {'affiliation-country': 'United States'}
# 74298  [{'affiliation-country': 'United States'}, {'a...
# 74299           {'affiliation-country': 'United States'}
# 74300  [{'affiliation-country': 'Turkey'}, {'affiliat...
# 74301                                               None
#
#                                                 coredata
# 0      {'srctype': 'j', 'eid': '2-s2.0-85083266658', ...
# 1      {'srctype': 'j', 'prism:issueIdentifier': '7',...
# 2      {'srctype': 'j', 'prism:issueIdentifier': '8',...
# 3      {'srctype': 'j', 'prism:issueIdentifier': '9',...
# 4      {'srctype': 'j', 'prism:issueIdentifier': '11'...
# ...                                                  ...
# 74297  {'srctype': 'j', 'eid': '2-s2.0-85092678139', ...
# 74298  {'srctype': 'j', 'eid': '2-s2.0-85087468210', ...
# 74299  {'srctype': 'j', 'eid': '2-s2.0-85092677974', ...
# 74300  {'srctype': 'j', 'prism:issueIdentifier': '4',...
# 74301                                               None
#
# [74302 rows x 2 columns]

# %%
def contains_only_None(dic):
    """
    This function inspects an dictionary and returns True if it solely contains None values.
    """
    return len(dic) == sum(value == None for value in dic.values())

# %%
def transpose_and_structure(df):
    """
    This function receives a DataFrame and returns it after tranposing. 
    """
    df = df.T
    if 'affiliation' not in df.columns:
        df['affiliation'] = None
    if 'coredata' not in df.columns:
        df['coredata'] = None
    return df

# %%
def append_fetched_data_to_df(df_current_extra_info, dic):
    """
    This function appends or inserts newly fetched data to the DataFrame containing scopus data.
    Moreover, this function is replacing None values with retrieved data. 
    df_current_extra_info holds the current entries read from the disk
    df_newly_fetched_transposed holds the newly fetched information in form ready to be inserted/appended
    """
    
    #checking if the dictionary contains value to append or insert to the existing information
    if contains_only_None(dic):
        #If a dictionary contains solely None values, they will be prepared for appending/inserting
        placeholder_entries = pd.DataFrame(np.empty((len(dict_new_extra_info),2),dtype=object),columns=['affiliation','coredata'], index=dict_new_extra_info.keys())
        df_newly_fetched_transposed = placeholder_entries
        print(df_newly_fetched_transposed)
    else:
        #Prior appending, the dictionary is transformed to a DataFrame
        df_newly_fetched = pd.DataFrame(dic)
        #For readability, the DataFrame is transposed
        df_newly_fetched_transposed = transpose_and_structure(df_newly_fetched)
        #The data is modified accordingly to the ethical guidelines
        df_newly_fetched_transposed = transform_to_ethical_correct_data(df_newly_fetched_transposed)
        print(df_newly_fetched_transposed)
    
    #Insert newly fetched rows which were previously not successful inserted/appended
    for index, row in df_newly_fetched_transposed.iterrows():
        #Insert to current extra info DataFrame because the row is existent
        if index in df_current_extra_info.index and row is not None:
            df_current_extra_info.loc[index] = row
        #Append to current extra info DataFrame because the row is new     
        if index not in df_current_extra_info.index:
            df_current_extra_info = df_current_extra_info.append(row, ignore_index=True)
            
    #Returning the DataFrame with newly fetched entries
    return df_current_extra_info

# %% [markdown]
# Thusly, the function handles the storing of newly fetched information to the disk.

# %%
def store_df_columns(df):
    """
    This function stores a DataFrame to a local file on the disk. 
    """
    df.to_pickle('extra_info_CS5099.pkl')

# %% [markdown]
# The length of the DataFrame containing the current information is assigned to a variable to be used for further processing. Therefore, the length will be used within a while loop as a starting index.

# %%
len_df_current_extra_info = len(df_current_extra_info)
len_df_current_extra_info
# Out:
# 74302

# %% [markdown]
# Subsequently, the SCOPUS API is fetched and stored within a dictionary.
# Besides, the print function is used to show the state of the process by displaying the latest fetched information.

# %%
dict_new_extra_info = dict()
len_dois = len(doi_counted)

def trigger_fetching():
    threshold = 0 
    i = len_df_current_extra_info
    while i < len_dois: 
        dict_new_extra_info[i] = fetch_scopus_api(client, doi_counted.index[i])
        print("Fetching index position: " + str(i) + " -> " +  doi_counted.index[i])
        i = i + 1 
        threshold = threshold + 1
        if threshold > 99:
            df_combined_extra_info = append_fetched_data_to_df(df_current_extra_info, dict_new_extra_info)
            store_df_columns(df_combined_extra_info)
            threshold = 0
            print("New batch saved.")

# %% [markdown]
# Thusly, the SCOPUS API fething process is triggered.

# %%
trigger_fetching()

# %% [markdown]
# The existing and newly fetched information is combined into one DataFrame and shown.

# %%
df_combined_extra_info = append_fetched_data_to_df(df_current_extra_info, dict_new_extra_info)
df_combined_extra_info
# Out:
# Empty DataFrame
# Columns: [affiliation, coredata]
# Index: []
#                                              affiliation  \
# 0      [{'affiliation-country': 'United States'}, {'a...
# 1      [{'affiliation-country': 'United States'}, {'a...
# 2      [{'affiliation-country': 'United States'}, {'a...
# 3      [{'affiliation-country': 'United States'}, {'a...
# 4      [{'affiliation-country': 'United States'}, {'a...
# ...                                                  ...
# 74297           {'affiliation-country': 'United States'}
# 74298  [{'affiliation-country': 'United States'}, {'a...
# 74299           {'affiliation-country': 'United States'}
# 74300  [{'affiliation-country': 'Turkey'}, {'affiliat...
# 74301                                               None
#
#                                                 coredata
# 0      {'srctype': 'j', 'eid': '2-s2.0-85083266658', ...
# 1      {'srctype': 'j', 'prism:issueIdentifier': '7',...
# 2      {'srctype': 'j', 'prism:issueIdentifier': '8',...
# 3      {'srctype': 'j', 'prism:issueIdentifier': '9',...
# 4      {'srctype': 'j', 'prism:issueIdentifier': '11'...
# ...                                                  ...
# 74297  {'srctype': 'j', 'eid': '2-s2.0-85092678139', ...
# 74298  {'srctype': 'j', 'eid': '2-s2.0-85087468210', ...
# 74299  {'srctype': 'j', 'eid': '2-s2.0-85092677974', ...
# 74300  {'srctype': 'j', 'prism:issueIdentifier': '4',...
# 74301                                               None
#
# [74302 rows x 2 columns]

# %% [markdown]
# Verifying that the returned None values are due to non-existent data and not to an invalid API-Key or later available information. Thusly, the function is used to fetched specific entries which could not be fetched previously.

# %%
def enrich_data():
    """
    This function fetches again the scopus API and solely asks for information which previously returned None. 
    """
    #Add a new column to the DataFrame containg the DOI's which are used to fetch the API
    ser_doi = pd.Series(doi_counted.index[:len_data])
    df_current_extra_info_checker = df_combined_extra_info
    
    #Fetching solely None entries 
    len_df_current_extra_info_checker = len(df_current_extra_info_checker)
    dict_new_extra_info_checker = dict()
    i = 0
    #Specify range to fetch. Otherwise comment out the next two lines.
    #i = 70000
    #len_df_current_extra_info_checker = 5000
    while i < len_df_current_extra_info_checker:
        #Fetch entries which miss informtion for affiliation and/or coredata 
        if df_current_extra_info_checker['affiliation'][i] == None or df_current_extra_info_checker['coredata'][i] == None:
            dict_new_extra_info_checker[i] = fetch_scopus_api(client, ser_doi[i])
            print("Fetched again index position: " + str(i) + " -> " +  ser_doi[i])
        i = i + 1

    #Check if at least one of the fetched values is not None, otherwise the process is finished
    if contains_only_None(dict_new_extra_info_checker):
        print("The scopus API did not returned new information for existing None values.")
    else:
        #There is new information to insert to the existing DataFrame
        df_combined_extra_info_fetched_again  = append_fetched_data_to_df(df_current_extra_info, dict_new_extra_info_checker)
        store_df_columns(df_combined_extra_info_fetched_again)

# %% [markdown]
# Print out the number of existent doi's and the length of the DataFrame holding the latest entries.

# %%
len_dois = len(doi_counted)
len_dois
# Out:
# 74302

# %%
len_data = len(df_combined_extra_info)
len_data
# Out:
# 74302

# %% [markdown]
# The next cell invokes the enrich_data() function when the SCOPUS API was fetched once with all doi's. Consequently, the DataFrame holding the latest fetched information must have the same length as the number of existent doi's.

# %%
if len_dois == len_data:
    enrich_data()
else:
    print("There are entries which are not fetched yet from the scopus API.")
# Out:
# Fetched again index position: 13 -> 10.1002/0471142700.nc0430s27
# Fetched again index position: 15 -> 10.1002/0471142735.im0700s95
# Fetched again index position: 16 -> 10.1002/0471142735.im0700s97
# Fetched again index position: 43 -> 10.1002/2211-5463.13058
# Fetched again index position: 52 -> 10.1002/acr.24487
# Fetched again index position: 53 -> 10.1002/acr2.11148
# Fetched again index position: 54 -> 10.1002/acr2.11164
# Fetched again index position: 55 -> 10.1002/acr2.11174
# Fetched again index position: 56 -> 10.1002/acr2.11207
# Fetched again index position: 68 -> 10.1002/adtp.202000034
# Fetched again index position: 69 -> 10.1002/adtp.202000129
# Fetched again index position: 85 -> 10.1002/aepp.13096
# Fetched again index position: 86 -> 10.1002/aepp.13100
# Fetched again index position: 88 -> 10.1002/aepp.13128
# Fetched again index position: 99 -> 10.1002/aisy.202000070
# Fetched again index position: 108 -> 10.1002/ajh.21744
# Fetched again index position: 142 -> 10.1002/ame2.12036
# Fetched again index position: 143 -> 10.1002/ame2.12047
# Fetched again index position: 144 -> 10.1002/ame2.12083
# Fetched again index position: 145 -> 10.1002/ame2.12088
# Fetched again index position: 146 -> 10.1002/amp2.10060
# Fetched again index position: 147 -> 10.1002/ams2.510
# Fetched again index position: 148 -> 10.1002/ams2.527
# Fetched again index position: 149 -> 10.1002/ams2.534
# Fetched again index position: 150 -> 10.1002/ams2.560
# Fetched again index position: 151 -> 10.1002/ams2.576
# Fetched again index position: 152 -> 10.1002/ams2.584
# Fetched again index position: 153 -> 10.1002/ams2.603
# Fetched again index position: 154 -> 10.1002/ams2.614
# Fetched again index position: 155 -> 10.1002/ams2.623
# Fetched again index position: 156 -> 10.1002/ana.24759
# Fetched again index position: 158 -> 10.1002/ana.25024
# Fetched again index position: 164 -> 10.1002/ana.410320224
# Fetched again index position: 165 -> 10.1002/anbr.202000035
# Fetched again index position: 166 -> 10.1002/ange.201206903
# Fetched again index position: 167 -> 10.1002/ange.201209222
# Fetched again index position: 168 -> 10.1002/ange.201500250
# Fetched again index position: 169 -> 10.1002/ange.201610372
# Fetched again index position: 170 -> 10.1002/ange.201914986
# Fetched again index position: 186 -> 10.1002/anr3.12074
# Fetched again index position: 192 -> 10.1002/art.1780210508
# Fetched again index position: 208 -> 10.1002/bco2.18
# Fetched again index position: 209 -> 10.1002/bco2.57
# Fetched again index position: 222 -> 10.1002/bio.783
# Fetched again index position: 226 -> 10.1002/biot.201000097
# Fetched again index position: 233 -> 10.1002/bip.21223
# Fetched again index position: 244 -> 10.1002/bjs.11746
# Fetched again index position: 249 -> 10.1002/bjs.11937
# Fetched again index position: 348 -> 10.1002/cmdc.201090022
# Fetched again index position: 397 -> 10.1002/csan.20139
# Fetched again index position: 416 -> 10.1002/ctm2.103
# Fetched again index position: 417 -> 10.1002/ctm2.158
# Fetched again index position: 418 -> 10.1002/ctm2.184
# Fetched again index position: 419 -> 10.1002/ctm2.189
# Fetched again index position: 420 -> 10.1002/ctm2.200
# Fetched again index position: 421 -> 10.1002/ctm2.206
# Fetched again index position: 422 -> 10.1002/ctm2.210
# Fetched again index position: 423 -> 10.1002/ctm2.215
# Fetched again index position: 424 -> 10.1002/ctm2.23
# Fetched again index position: 425 -> 10.1002/ctm2.231
# Fetched again index position: 426 -> 10.1002/ctm2.28
# Fetched again index position: 427 -> 10.1002/ctm2.52
# Fetched again index position: 443 -> 10.1002/dch.30332
# Fetched again index position: 444 -> 10.1002/dch.30335
# Fetched again index position: 465 -> 10.1002/ebch.543
# Fetched again index position: 496 -> 10.1002/ehf2.12870
# Fetched again index position: 526 -> 10.1002/eji.200990224
# Fetched again index position: 550 -> 10.1002/emp2.12040
# Fetched again index position: 551 -> 10.1002/emp2.12041
# Fetched again index position: 552 -> 10.1002/emp2.12063
# Fetched again index position: 553 -> 10.1002/emp2.12076
# Fetched again index position: 554 -> 10.1002/emp2.12080
# Fetched again index position: 555 -> 10.1002/emp2.12081
# Fetched again index position: 556 -> 10.1002/emp2.12082
# Fetched again index position: 557 -> 10.1002/emp2.12098
# Fetched again index position: 558 -> 10.1002/emp2.12102
# Fetched again index position: 559 -> 10.1002/emp2.12127
# Fetched again index position: 560 -> 10.1002/emp2.12128
# Fetched again index position: 561 -> 10.1002/emp2.12136
# Fetched again index position: 562 -> 10.1002/emp2.12137
# Fetched again index position: 563 -> 10.1002/emp2.12145
# Fetched again index position: 564 -> 10.1002/emp2.12158
# Fetched again index position: 565 -> 10.1002/emp2.12183
# Fetched again index position: 566 -> 10.1002/emp2.12194
# Fetched again index position: 567 -> 10.1002/emp2.12204
# Fetched again index position: 568 -> 10.1002/emp2.12205
# Fetched again index position: 569 -> 10.1002/emp2.12210
# Fetched again index position: 570 -> 10.1002/emp2.12219
# Fetched again index position: 571 -> 10.1002/emp2.12220
# Fetched again index position: 572 -> 10.1002/emp2.12224
# Fetched again index position: 573 -> 10.1002/emp2.12230
# Fetched again index position: 574 -> 10.1002/emp2.12280
# Fetched again index position: 575 -> 10.1002/emp2.12286
# Fetched again index position: 576 -> 10.1002/emp2.12292
# Fetched again index position: 577 -> 10.1002/emp2.12293
# Fetched again index position: 578 -> 10.1002/emp2.12305
# Fetched again index position: 579 -> 10.1002/emp2.12307
# Fetched again index position: 580 -> 10.1002/emp2.12313
# Fetched again index position: 581 -> 10.1002/emp2.12316
# Fetched again index position: 582 -> 10.1002/emp2.12317
# Fetched again index position: 583 -> 10.1002/emp2.12321
# Fetched again index position: 584 -> 10.1002/emp2.12325
# Fetched again index position: 585 -> 10.1002/emp2.12356
# Fetched again index position: 586 -> 10.1002/emp2.12359
# Fetched again index position: 587 -> 10.1002/eom2.12045
# Fetched again index position: 609 -> 10.1002/ffo2.34
# Fetched again index position: 610 -> 10.1002/fft2.29
# Fetched again index position: 615 -> 10.1002/gch2.202000012
# Fetched again index position: 616 -> 10.1002/gch2.202000038
# Fetched again index position: 617 -> 10.1002/gch2.202000046
# Fetched again index position: 618 -> 10.1002/gch2.202000067
# Fetched again index position: 620 -> 10.1002/geo2.66
# Fetched again index position: 628 -> 10.1002/glia.22530
# Fetched again index position: 634 -> 10.1002/hast.1125
# Fetched again index position: 671 -> 10.1002/hep.1840380505
# Fetched again index position: 672 -> 10.1002/hep.1840400504
# Fetched again index position: 673 -> 10.1002/hep.20926
# Fetched again index position: 681 -> 10.1002/hep.28798
# Fetched again index position: 687 -> 10.1002/hep4.1269
# Fetched again index position: 688 -> 10.1002/hep4.1579
# Fetched again index position: 689 -> 10.1002/hep4.1585
# Fetched again index position: 690 -> 10.1002/hep4.1586
# Fetched again index position: 691 -> 10.1002/hep4.1620
# Fetched again index position: 692 -> 10.1002/hep4.1650
# Fetched again index position: 718 -> 10.1002/ijc.25875
# Fetched again index position: 731 -> 10.1002/itl2.247
# Fetched again index position: 736 -> 10.1002/j.1537-2197.1962.tb15020.x
# Fetched again index position: 737 -> 10.1002/j.1537-2197.1968.tb07429.x
# Fetched again index position: 738 -> 10.1002/j.1537-2197.1988.tb13450.x
# Fetched again index position: 741 -> 10.1002/j.2167-4086.2003.tb00653.x
# Fetched again index position: 760 -> 10.1002/jcb.240140102
# Fetched again index position: 761 -> 10.1002/jcb.240210607
# Fetched again index position: 762 -> 10.1002/jcb.240290605
# Fetched again index position: 763 -> 10.1002/jcb.240410506
# Fetched again index position: 764 -> 10.1002/jcb.240440602
# Fetched again index position: 765 -> 10.1002/jcb.240530803
# Fetched again index position: 766 -> 10.1002/jcb.240560809
# Fetched again index position: 819 -> 10.1002/jctb.5000190302
# Fetched again index position: 865 -> 10.1002/jhbp.873
# Fetched again index position: 1064 -> 10.1002/jmv.25493
# Fetched again index position: 1116 -> 10.1002/jmv.25894
# Fetched again index position: 1307 -> 10.1002/jsp2.1122
# Fetched again index position: 1308 -> 10.1002/jss.400140505
# Fetched again index position: 1312 -> 10.1002/jtr.450
# Fetched again index position: 1313 -> 10.1002/jtr.579
# Fetched again index position: 1335 -> 10.1002/lary.28896
# Fetched again index position: 1347 -> 10.1002/leap.1314
# Fetched again index position: 1348 -> 10.1002/leap.1332
# Fetched again index position: 1349 -> 10.1002/lim2.1
# Fetched again index position: 1350 -> 10.1002/lio2.384
# Fetched again index position: 1351 -> 10.1002/lio2.386
# Fetched again index position: 1352 -> 10.1002/lio2.389
# Fetched again index position: 1353 -> 10.1002/lio2.439
# Fetched again index position: 1354 -> 10.1002/lio2.445
# Fetched again index position: 1355 -> 10.1002/lio2.484
# Fetched again index position: 1356 -> 10.1002/lio2.498
# Fetched again index position: 1357 -> 10.1002/lio2.507
# Fetched again index position: 1362 -> 10.1002/lt.20208
# Fetched again index position: 1383 -> 10.1002/mco2.14
# Fetched again index position: 1391 -> 10.1002/mds3.10112
# Fetched again index position: 1422 -> 10.1002/nau.22577
# Fetched again index position: 1423 -> 10.1002/nau.23386
# Fetched again index position: 1480 -> 10.1002/path.1711410407
# Fetched again index position: 1481 -> 10.1002/path.1711640412
# Fetched again index position: 1482 -> 10.1002/path.4631
# Fetched again index position: 1488 -> 10.1002/pbc.25715
# Fetched again index position: 1489 -> 10.1002/pbc.25998
# Fetched again index position: 1490 -> 10.1002/pbc.27057
# Fetched again index position: 1542 -> 10.1002/ppul.1950040208
# Fetched again index position: 1543 -> 10.1002/ppul.1950110604
# Fetched again index position: 1545 -> 10.1002/ppul.20142
# Fetched again index position: 1548 -> 10.1002/ppul.20700
# Fetched again index position: 1550 -> 10.1002/ppul.21133
# Fetched again index position: 1554 -> 10.1002/ppul.21339
# Fetched again index position: 1556 -> 10.1002/ppul.21582
# Fetched again index position: 1557 -> 10.1002/ppul.21583
# Fetched again index position: 1560 -> 10.1002/ppul.22681
# Fetched again index position: 1561 -> 10.1002/ppul.22682
# Fetched again index position: 1564 -> 10.1002/ppul.23068
# Fetched again index position: 1569 -> 10.1002/ppul.23296
# Fetched again index position: 1572 -> 10.1002/ppul.23455
# Fetched again index position: 1575 -> 10.1002/ppul.23576
# Fetched again index position: 1577 -> 10.1002/ppul.23729
# Fetched again index position: 1580 -> 10.1002/ppul.24034
# Fetched again index position: 1582 -> 10.1002/ppul.24152
# Fetched again index position: 1584 -> 10.1002/ppul.24373
# Fetched again index position: 1595 -> 10.1002/pra2.233
# Fetched again index position: 1596 -> 10.1002/pra2.246
# Fetched again index position: 1597 -> 10.1002/pra2.252
# Fetched again index position: 1598 -> 10.1002/pra2.269
# Fetched again index position: 1599 -> 10.1002/pra2.272
# Fetched again index position: 1600 -> 10.1002/pra2.295
# Fetched again index position: 1601 -> 10.1002/pra2.313
# Fetched again index position: 1602 -> 10.1002/pra2.338
# Fetched again index position: 1603 -> 10.1002/pra2.349
# Fetched again index position: 1604 -> 10.1002/pra2.363
# Fetched again index position: 1605 -> 10.1002/pra2.370
# Fetched again index position: 1606 -> 10.1002/pra2.378
# Fetched again index position: 1607 -> 10.1002/pra2.397
# Fetched again index position: 1611 -> 10.1002/prm2.12026
# Fetched again index position: 1614 -> 10.1002/pro.2113
# Fetched again index position: 1618 -> 10.1002/pro.2823
# Fetched again index position: 1624 -> 10.1002/pro.3349
# Fetched again index position: 1626 -> 10.1002/pro.3513
# Fetched again index position: 1657 -> 10.1002/psb.1111
# Fetched again index position: 1658 -> 10.1002/psb.1550
# Fetched again index position: 1659 -> 10.1002/psb.1843
# Fetched again index position: 1660 -> 10.1002/psb.285
# Fetched again index position: 1661 -> 10.1002/psb.723
# Fetched again index position: 1662 -> 10.1002/psc.1089
# Fetched again index position: 1663 -> 10.1002/psc.1090
# Fetched again index position: 1664 -> 10.1002/psc.2449
# Fetched again index position: 1668 -> 10.1002/psc.617
# Fetched again index position: 1669 -> 10.1002/psc.618
# Fetched again index position: 1670 -> 10.1002/psc.797
# Fetched again index position: 1684 -> 10.1002/qsar.19900090309
# Fetched again index position: 1686 -> 10.1002/qsar.200590025
# Fetched again index position: 1687 -> 10.1002/qsar.200590028
# Fetched again index position: 1688 -> 10.1002/qsar.200590050
# Fetched again index position: 1689 -> 10.1002/qsar.200690010
# Fetched again index position: 1749 -> 10.1002/sca.4950160315
# Fetched again index position: 1751 -> 10.1002/sctm.20-0181
# Fetched again index position: 1773 -> 10.1002/tkm2.1258
# Fetched again index position: 1776 -> 10.1002/trc2.12085
# Fetched again index position: 1778 -> 10.1002/trc2.12108
# Fetched again index position: 1779 -> 10.1002/tre.750
# Fetched again index position: 1785 -> 10.1002/viw2.4
# Fetched again index position: 1822 -> 10.1002/ygh2.418
# Fetched again index position: 1829 -> 10.1006/jmbi.1997.1433
# Fetched again index position: 1865 -> 10.1007/0-387-23380-6_4
# Fetched again index position: 1866 -> 10.1007/0-387-23685-6_2
# Fetched again index position: 1867 -> 10.1007/0-387-23685-6_9
# Fetched again index position: 1868 -> 10.1007/0-387-24103-5_12
# Fetched again index position: 1869 -> 10.1007/0-387-25228-2_4
# Fetched again index position: 1870 -> 10.1007/0-387-25741-1_10
# Fetched again index position: 1872 -> 10.1007/0-387-27375-1_15
# Fetched again index position: 1873 -> 10.1007/0-387-27478-2_2
# Fetched again index position: 1874 -> 10.1007/0-387-27478-2_5
# Fetched again index position: 1875 -> 10.1007/0-387-27652-1_18
# Fetched again index position: 1878 -> 10.1007/0-387-28146-0_14
# Fetched again index position: 1879 -> 10.1007/0-387-28159-2_3
# Fetched again index position: 1880 -> 10.1007/0-387-30105-4_16
# Fetched again index position: 1881 -> 10.1007/0-387-30332-4_9
# Fetched again index position: 1882 -> 10.1007/0-387-30744-3_1
# Fetched again index position: 1886 -> 10.1007/0-387-36278-9_22
# Fetched again index position: 1887 -> 10.1007/0-387-70714-x_11
# Fetched again index position: 1888 -> 10.1007/1-4020-2219-0_8
# Fetched again index position: 1889 -> 10.1007/1-4020-3384-2_1
# Fetched again index position: 1890 -> 10.1007/1-4020-3395-8_10
# Fetched again index position: 1891 -> 10.1007/1-4020-3484-9_9
# Fetched again index position: 1893 -> 10.1007/1-4020-4196-9_1
# Fetched again index position: 1895 -> 10.1007/1-4020-4842-4_7
# Fetched again index position: 1897 -> 10.1007/1-4020-5149-2_4
# Fetched again index position: 1898 -> 10.1007/1-4020-5252-9_1
# Fetched again index position: 1899 -> 10.1007/1-4020-5466-1_10
# Fetched again index position: 1901 -> 10.1007/10.1007/978-90-368-1469-0_2
# Fetched again index position: 1924 -> 10.1007/124_2018_20
# Fetched again index position: 1926 -> 10.1007/128_2012_326
# Fetched again index position: 1927 -> 10.1007/128_2012_413
# Fetched again index position: 1929 -> 10.1007/13836_2018_31
# Fetched again index position: 1936 -> 10.1007/3-540-26527-9_26
# Fetched again index position: 1937 -> 10.1007/3-540-26584-8_5
# Fetched again index position: 1938 -> 10.1007/3-540-26587-2_11
# Fetched again index position: 1942 -> 10.1007/3-540-27136-8_5
# Fetched again index position: 1943 -> 10.1007/3-540-27136-8_6
# Fetched again index position: 1946 -> 10.1007/3-540-27385-9_82
# Fetched again index position: 1948 -> 10.1007/3-540-28954-2_13
# Fetched again index position: 1949 -> 10.1007/3-540-28977-1_20
# Fetched again index position: 1950 -> 10.1007/3-540-29048-6_7
# Fetched again index position: 1951 -> 10.1007/3-540-29184-9_22
# Fetched again index position: 1952 -> 10.1007/3-540-29425-2_6
# Fetched again index position: 1953 -> 10.1007/3-540-30328-6_2
# Fetched again index position: 1954 -> 10.1007/3-540-31176-9_43
# Fetched again index position: 1956 -> 10.1007/3-540-31303-6_103
# Fetched again index position: 1957 -> 10.1007/3-540-31303-6_129
# Fetched again index position: 1958 -> 10.1007/3-540-31920-4_1
# Fetched again index position: 1959 -> 10.1007/3-540-32367-8_15
# Fetched again index position: 1960 -> 10.1007/3-540-34525-6_3
# Fetched again index position: 1961 -> 10.1007/3-7643-7339-3_1
# Fetched again index position: 1962 -> 10.1007/3-7643-7339-3_5
# Fetched again index position: 1963 -> 10.1007/3-7643-7339-3_7
# Fetched again index position: 1964 -> 10.1007/3-7643-7381-4_1
# Fetched again index position: 1965 -> 10.1007/3-7643-7408-x_21
# Fetched again index position: 1966 -> 10.1007/3-7643-7408-x_7
# Fetched again index position: 1967 -> 10.1007/3-7908-1624-8_68
# Fetched again index position: 1968 -> 10.1007/4-431-26925-8_1
# Fetched again index position: 1991 -> 10.1007/82_2012_239
# Fetched again index position: 1994 -> 10.1007/82_2012_259
# Fetched again index position: 1995 -> 10.1007/82_2012_263
# Fetched again index position: 1997 -> 10.1007/82_2012_271
# Fetched again index position: 1999 -> 10.1007/82_2013_317
# Fetched again index position: 2006 -> 10.1007/978-0-230-55477-1_14
# Fetched again index position: 2007 -> 10.1007/978-0-230-55477-1_4
# Fetched again index position: 2020 -> 10.1007/978-0-387-25842-3_2
# Fetched again index position: 2021 -> 10.1007/978-0-387-29844-3_12
# Fetched again index position: 2022 -> 10.1007/978-0-387-29845-0_1
# Fetched again index position: 2046 -> 10.1007/978-0-387-34163-7_17
# Fetched again index position: 2048 -> 10.1007/978-0-387-46364-3_2
# Fetched again index position: 2049 -> 10.1007/978-0-387-49009-0_10
# Fetched again index position: 2053 -> 10.1007/978-0-387-68825-1_1
# Fetched again index position: 2056 -> 10.1007/978-0-387-71611-4_26
# Fetched again index position: 2057 -> 10.1007/978-0-387-71613-8_18
# Fetched again index position: 2060 -> 10.1007/978-0-387-73637-2_3
# Fetched again index position: 2061 -> 10.1007/978-0-387-75113-9_23
# Fetched again index position: 2062 -> 10.1007/978-0-387-75113-9_32
# Fetched again index position: 2063 -> 10.1007/978-0-387-75113-9_36
# Fetched again index position: 2064 -> 10.1007/978-0-387-75240-2_8
# Fetched again index position: 2066 -> 10.1007/978-0-387-76842-7_10
# Fetched again index position: 2067 -> 10.1007/978-0-387-77040-6_1
# Fetched again index position: 2069 -> 10.1007/978-0-387-79208-8_3
# Fetched again index position: 2070 -> 10.1007/978-0-387-79727-4_4
# Fetched again index position: 2071 -> 10.1007/978-0-387-79876-9_1
# Fetched again index position: 2072 -> 10.1007/978-0-387-84841-9_7
# Fetched again index position: 2074 -> 10.1007/978-0-387-87429-6_63
# Fetched again index position: 2075 -> 10.1007/978-0-387-89382-2_14
# Fetched again index position: 2076 -> 10.1007/978-0-387-89382-2_7
# Fetched again index position: 2077 -> 10.1007/978-0-387-98063-8_10
# Fetched again index position: 2267 -> 10.1007/978-1-4939-3414-0_19
# Fetched again index position: 2269 -> 10.1007/978-1-4939-6377-5_29
# Fetched again index position: 2270 -> 10.1007/978-1-4939-6377-5_47
# Fetched again index position: 2273 -> 10.1007/978-1-4939-6966-1_14
# Fetched again index position: 2274 -> 10.1007/978-1-4939-6966-1_4
# Fetched again index position: 2278 -> 10.1007/978-1-4939-7431-3_9
# Fetched again index position: 2285 -> 10.1007/978-1-4939-9034-4_45
# Fetched again index position: 2286 -> 10.1007/978-1-4939-9034-4_47
# Fetched again index position: 2290 -> 10.1007/978-1-59259-785-7_29
# Fetched again index position: 2291 -> 10.1007/978-1-59259-880-9_21
# Fetched again index position: 2292 -> 10.1007/978-1-59259-921-9_10
# Fetched again index position: 2298 -> 10.1007/978-1-59745-127-7_17
# Fetched again index position: 2308 -> 10.1007/978-1-59745-240-3_1
# Fetched again index position: 2309 -> 10.1007/978-1-59745-240-3_2
# Fetched again index position: 2311 -> 10.1007/978-1-59745-326-4_13
# Fetched again index position: 2312 -> 10.1007/978-1-59745-326-4_15
# Fetched again index position: 2313 -> 10.1007/978-1-59745-326-4_16
# Fetched again index position: 2320 -> 10.1007/978-1-59745-501-5_21
# Fetched again index position: 2321 -> 10.1007/978-1-59745-501-5_8
# Fetched again index position: 2322 -> 10.1007/978-1-59745-528-2_3
# Fetched again index position: 2326 -> 10.1007/978-1-59745-569-5_34
# Fetched again index position: 2327 -> 10.1007/978-1-60327-034-2_2
# Fetched again index position: 2330 -> 10.1007/978-1-60327-297-1_23
# Fetched again index position: 2331 -> 10.1007/978-1-60327-297-1_25
# Fetched again index position: 2334 -> 10.1007/978-1-60327-385-5_29
# Fetched again index position: 2336 -> 10.1007/978-1-60327-538-5_11
# Fetched again index position: 2337 -> 10.1007/978-1-60327-553-8_2
# Fetched again index position: 2341 -> 10.1007/978-1-60761-817-1_17
# Fetched again index position: 2352 -> 10.1007/978-1-84628-715-2_108
# Fetched again index position: 2353 -> 10.1007/978-1-84628-740-4_8
# Fetched again index position: 2354 -> 10.1007/978-1-84800-352-1_13
# Fetched again index position: 2355 -> 10.1007/978-1-84800-917-2_4
# Fetched again index position: 2356 -> 10.1007/978-1-84800-925-7_9
# Fetched again index position: 2359 -> 10.1007/978-1-84996-133-2_7
# Fetched again index position: 2364 -> 10.1007/978-3-030-03053-7_13
# Fetched again index position: 2365 -> 10.1007/978-3-030-03053-7_15
# Fetched again index position: 2366 -> 10.1007/978-3-030-03053-7_9
# Fetched again index position: 2367 -> 10.1007/978-3-030-03071-1_13
# Fetched again index position: 2369 -> 10.1007/978-3-030-03285-2_3
# Fetched again index position: 2370 -> 10.1007/978-3-030-03344-6_24
# Fetched again index position: 2371 -> 10.1007/978-3-030-04691-0_3
# Fetched again index position: 2372 -> 10.1007/978-3-030-04801-3_7
# Fetched again index position: 2373 -> 10.1007/978-3-030-05070-2_24
# Fetched again index position: 2375 -> 10.1007/978-3-030-05357-4_3
# Fetched again index position: 2377 -> 10.1007/978-3-030-10811-3_10
# Fetched again index position: 2380 -> 10.1007/978-3-030-15224-6_6
# Fetched again index position: 2381 -> 10.1007/978-3-030-15346-5_13
# Fetched again index position: 2382 -> 10.1007/978-3-030-15903-0_20
# Fetched again index position: 2383 -> 10.1007/978-3-030-16061-6_7
# Fetched again index position: 2384 -> 10.1007/978-3-030-16257-3_1
# Fetched again index position: 2387 -> 10.1007/978-3-030-17148-3_8
# Fetched again index position: 2388 -> 10.1007/978-3-030-17385-2_2
# Fetched again index position: 2389 -> 10.1007/978-3-030-17474-3_14
# Fetched again index position: 2390 -> 10.1007/978-3-030-17474-3_3
# Fetched again index position: 2391 -> 10.1007/978-3-030-17693-8_7
# Fetched again index position: 2392 -> 10.1007/978-3-030-17819-2_5
# Fetched again index position: 2393 -> 10.1007/978-3-030-18623-4_6
# Fetched again index position: 2394 -> 10.1007/978-3-030-19055-2_4
# Fetched again index position: 2395 -> 10.1007/978-3-030-20820-2_8
# Fetched again index position: 2396 -> 10.1007/978-3-030-21084-7_6
# Fetched again index position: 2397 -> 10.1007/978-3-030-21267-4_18
# Fetched again index position: 2398 -> 10.1007/978-3-030-21309-1_7
# Fetched again index position: 2399 -> 10.1007/978-3-030-21840-9_4
# Fetched again index position: 2400 -> 10.1007/978-3-030-21859-1_8
# Fetched again index position: 2408 -> 10.1007/978-3-030-25494-0_1
# Fetched again index position: 2409 -> 10.1007/978-3-030-25553-4_14
# Fetched again index position: 2410 -> 10.1007/978-3-030-26795-7_1
# Fetched again index position: 2411 -> 10.1007/978-3-030-26795-7_7
# Fetched again index position: 2412 -> 10.1007/978-3-030-26961-6_73
# Fetched again index position: 2413 -> 10.1007/978-3-030-27874-8_4
# Fetched again index position: 2414 -> 10.1007/978-3-030-28384-1_6
# Fetched again index position: 2415 -> 10.1007/978-3-030-28634-7_11
# Fetched again index position: 2421 -> 10.1007/978-3-030-29462-5_10
# Fetched again index position: 2423 -> 10.1007/978-3-030-29966-8_12
# Fetched again index position: 2425 -> 10.1007/978-3-030-30730-1_51
# Fetched again index position: 2426 -> 10.1007/978-3-030-31507-8_18
# Fetched again index position: 2427 -> 10.1007/978-3-030-32288-5_6
# Fetched again index position: 2428 -> 10.1007/978-3-030-33136-8_1
# Fetched again index position: 2429 -> 10.1007/978-3-030-33645-5_2
# Fetched again index position: 2430 -> 10.1007/978-3-030-33803-9_13
# Fetched again index position: 2434 -> 10.1007/978-3-030-35139-7_7
# Fetched again index position: 2435 -> 10.1007/978-3-030-35260-8_8
# Fetched again index position: 2436 -> 10.1007/978-3-030-36171-6_2
# Fetched again index position: 2437 -> 10.1007/978-3-030-36244-7_3
# Fetched again index position: 2439 -> 10.1007/978-3-030-36525-7_5
# Fetched again index position: 2440 -> 10.1007/978-3-030-36966-8_3
# Fetched again index position: 2441 -> 10.1007/978-3-030-36966-8_8
# Fetched again index position: 2443 -> 10.1007/978-3-030-37397-9_1
# Fetched again index position: 2444 -> 10.1007/978-3-030-38141-7_4
# Fetched again index position: 2445 -> 10.1007/978-3-030-38257-5_9
# Fetched again index position: 2446 -> 10.1007/978-3-030-38569-9_1
